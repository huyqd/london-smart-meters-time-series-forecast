# %%
# %load_ext autoreload
# %autoreload 2

# %%
import polars as pl
from statsforecast import StatsForecast
from statsmodels.stats.diagnostic import acorr_ljungbox
from utilsforecast.losses import *

from plotting_utils import (
    plot_ets_components,
    plot_residuals_diagnostic,
)
from plotting_utils import (
    plotly_series as plot_series,
)
from summary_utils import print_ets_fitted_summary

# %% [markdown]
# # Exponential Smoothing Models for Electricity Forecasting: A Comprehensive Pedagogical Guide
#
# Welcome to this hands-on tutorial on exponential smoothing models for time series forecasting! In this notebook, we explore the complete family of exponential smoothing models—from the simplest approach to advanced frameworks—with a focus on understanding **why** each method works and **when** to apply it.
#
# ## Table of Contents
#
# This notebook is organized into 8 comprehensive parts. **Note on Organization:** Most parts appear in logical sequence. Part 5 (Damped Trends) appears before Part 3-4, but the comprehensive Table of Contents below shows the intended reading order:
#
# 1. **Part 0:** Foundations - Exponential Weighting Scheme
#    *Understand why exponential smoothing is called "exponential" and why recursion works*
#
# 2. **Part 1:** Simple Exponential Smoothing (SES / ETS(A,N,N))
#    *The foundational model for baseline forecasting*
#
# 3. **Part 2:** Holt's Linear Trend Method (ETS(A,A,N))
#    *Adding trend capability for non-seasonal trending data*
#
# 4. **Part 3:** Holt-Winters Additive Seasonality (ETS(A,A,A))
#    *Capturing additive seasonal patterns alongside trend*
#
# 5. **Part 4:** Multiplicative Seasonality (ETS(A,A,M))
#    *When seasonal swings scale with demand level*
#
# 6. **Part 5:** Damped Trend Models (ETS(A,Ad,A) and ETS(A,Ad,M))
#    *Preventing unrealistic long-term trend growth*
#
# 7. **Part 6:** Complete ETS Framework - All 30 Models
#    *Systematic taxonomy of all exponential smoothing variants with decision framework*
#
# 8. **Part 7:** Residual Diagnostics and Model Validation
#    *How to check if your model has captured the data's structure*
#
# 9. **Part 8:** Comprehensive Summary and Practical Implementation
#    *Bringing it all together with electricity forecasting strategies*
#
# ## Learning Objectives
#
# By the end of this notebook, you will:
#
# 1. **Understand the intuition** behind exponential weighting and why recent observations matter more
# 2. **Master state-space formulations** and learn how exponential smoothing can be viewed as a recursive optimization process
# 3. **Recognize the limitations** of single-seasonality models for multi-seasonal electricity data
# 4. **Make informed decisions** about model selection using the complete ETS (Error-Trend-Seasonal) framework
#
# ## Notebook Structure
#
# This notebook combines:
#
# - **Pedagogical explanations**: Each concept explained from multiple angles (intuitive, mathematical, practical)
# - **Mathematical rigor**: Complete state-space formulations, derivations, and proofs
# - **Code examples**: Practical implementation with `statsforecast` and visualization
# - **Electricity-specific guidance**: When each model is suitable for household vs aggregated data
# - **Diagnostic tools**: Residual analysis and model validation techniques
#
# ## Who This Is For
#
# This content is designed for **beginners** to time series forecasting who want deep understanding, not just recipes. Each concept builds on the previous one, so **read sequentially following the Table of Contents above**. Mathematical formulas are provided with explanations—don't skip them, as they reveal how the models actually work.
#
# ## The Big Picture: Why Exponential Smoothing?
#
# Exponential smoothing is powerful because it:
#
# 1. **Is computationally efficient** - uses only recursive updates, no matrix inversions
# 2. **Provides interpretable components** - you can see level, trend, and seasonality separately
# 3. **Adapts automatically** - learns the speed of change through smoothing parameters
# 4. **Works well in practice** - decades of real-world validation on diverse data
# 5. **Scales to production** - can forecast millions of time series simultaneously
#
# For electricity consumption forecasting, exponential smoothing provides a strong baseline that captures essential patterns (daily cycles, weekly rhythms) while remaining transparent and implementable in real-time systems.
#
# ---
#
# **Let's begin our journey into exponential smoothing!**

# %% [markdown]
# ## Data Preparation
#
# We'll use a single household's half-hourly electricity consumption data. This keeps things simple and lets us focus on model behavior.
#
# Feel free to swap in your own data or try with other households!

# %%
id_ = "unique_id"
time_ = "ds"
target_ = "y"
id_col = pl.col(id_)
time_col = pl.col(time_)
target_col = pl.col(target_)

# %%
import polars as pl

data = pl.read_parquet(
    "data/london_smart_meters/preprocessed/london_smart_meters_merged_block_0-7.parquet"
)
timestamp = data.group_by("LCLid").agg(
    pl.datetime_range(
        start=pl.col("start_timestamp"),
        end=pl.col("start_timestamp").dt.offset_by(
            pl.format("{}m", pl.col("series_length").sub(1).mul(30))
        ),
        interval="30m",
    ).alias("ds"),
)
data = timestamp.join(data, on="LCLid", how="inner").rename(
    {"LCLid": "unique_id", "energy_consumption": "y"}
)
data = (
    data.filter(pl.col("file").eq("block_7"))
    .select([time_, id_, target_])
    .explode([time_, target_])
)
selected_id = "MAC000193"
data = data.filter(id_col.eq(selected_id)).with_columns(
    target_col.forward_fill().backward_fill()
)
data.head(5)

# %%
plot_series(data)

# %% [markdown]
# # 0. Introduction to Exponential Smoothing
#
# Exponential Smoothing is a foundational technique in time series forecasting, widely used for its simplicity and effectiveness. At its core, exponential smoothing helps us predict future values by giving more weight to recent observations, while not completely discarding older data. This makes it especially useful for data that may have trends or seasonality.
#
# #### Why "Exponential"?
#
# The term "exponential" comes from the way the method assigns weights to past observations. Instead of treating all past data equally, exponential smoothing applies exponentially decreasing weights as the observations get older. This means the most recent data points have the greatest influence on the forecast, which often makes sense in real-world scenarios where recent trends are more relevant.

# %% [markdown]
# # Part 1. Simple Exponential Smoothing (SES)
#
# ## What is SES?
#
# **Simple Exponential Smoothing** is the most basic exponential smoothing model. It is designed for time series data with **no clear trend or seasonality**. SES produces forecasts by taking a weighted average of past observations, where the weights decrease exponentially for older data.
#
# ### Weighted Average Form of SES
# The forecast equation is:
#
# $$
# \hat{y}_{t+1} = \alpha y_t + (1-\alpha) \hat{y}_t
# $$
#
# - $y_t$ is the actual value at time $t$
# - $\hat{y}_t$ is the forecast at time $t$
# - $\alpha$ is the smoothing parameter $(0 < \alpha < 1)$
#
# ### Component Form of SES
#
# The **component form** of Simple Exponential Smoothing describes how the level is updated at each time step:
#
# $$
# \ell_t = \alpha y_t + (1-\alpha)\ell_{t-1} \\\\
# \hat{y}_{t+1|t} = \ell_t
# $$
#
# - $\ell_t$ is the estimated level at time $t$
# - $\alpha$ is the smoothing parameter $(0 < \alpha < 1)$
# - $\hat{y}_{t+1|t}$ is the forecast for the next time point
#
# This form shows that SES maintains a single component (the level), which is updated as new data arrives.
#
# **Forecast Profile for SES**
#
# The SES forecast for all future time points is constant and equal to the last estimated level:
#
# $$
# \hat{y}_{T+h|T} = \ell_T \quad \text{for} \quad h = 1, 2, 3, \ldots
# $$
#
# This means the forecast profile is completely flat—no matter how far ahead you forecast, the prediction does not change. This is why SES cannot capture trends or seasonality.
#
# ## Is SES suitable for electricity data?
#
# Electricity consumption data almost always has **strong seasonality** (daily, weekly) and sometimes a trend. SES is **not suitable** for such data, but it's a good baseline and helps us see why more complex models are needed.

# %%
from statsforecast.models import AutoETS

fcst_ses = StatsForecast(
    models=[AutoETS(season_length=48, model="ANN", alias="SES")],
    freq="30m",
)
ses_fit = fcst_ses.fit(df=data)

ses_forecast = fcst_ses.cross_validation(
    df=data.select([id_, time_, target_col.forward_fill()]),
    h=48,
    step_size=1,
    n_windows=1,
    fitted=True,
).drop("cutoff")
plot_series(data, ses_forecast, max_insample_length=200)

# %%
model_dict = ses_fit.fitted_[0, 0].model_
states = model_dict["states"]
residuals = model_dict["residuals"]

plot_ets_components(
    time=data.get_column(time_),
    observed=data.get_column(target_),
    level=states[:, 0],
    slope=None,
    season=None,
    resid=residuals,
)

# %% [markdown]
# ## Interpretation
#
# - SES will produce a flat forecast (no trend, no seasonality).
# - For electricity data, this will **miss all daily and weekly patterns**.
# - Use SES only as a baseline to see how much improvement you get from more advanced models.

# %%
print_ets_fitted_summary(ses_fit, model_alias="SES", model_idx=0)

# %% [markdown]
# The components string sometimes appears as `'ANNN'` instead of `'ANN'` because some implementations (including statsforecast and some R packages) use a four-letter code to explicitly indicate the error, trend, seasonality, and damped trend components:
# - 1st letter: Error type (A = Additive, M = Multiplicative)
# - 2nd letter: Trend type (N = None, A = Additive, M = Multiplicative)
# - 3rd letter: Seasonality type (N = None, A = Additive, M = Multiplicative)
# - 4th letter: Damped trend (N = Not damped, A/M = damped)
#
# For SES (ETS(A,N,N)), there is no trend, no seasonality, and no damping, so the code is `'ANNN'`.
# If a model has a damped trend, the fourth letter would be different (e.g., `'AAND'` for additive error, additive trend, no seasonality, additive damped trend).
# In summary, `'ANNN'` is just a more explicit version of `'ANN'`, making the presence or absence of damping clear.

# %% [markdown]
# # 2. Holt’s Linear Trend Method
#
# ## What is Holt’s Method?
#
# **Holt's Linear Trend** method extends SES by adding a trend component. It is suitable for data with a trend but **no seasonality**.
#
# The equations are:
#
# $$
# \begin{align*}
# \ell_t &= \alpha y_t + (1-\alpha)(\ell_{t-1} + b_{t-1}) \\
# b_t &= \beta (\ell_t - \ell_{t-1}) + (1-\beta) b_{t-1} \\
# \hat{y}_{t+h} &= \ell_t + h b_t
# \end{align*}
# $$
#
# - $\ell_t$ is the level at time $t$
# - $b_t$ is the trend (slope) at time $t$
# - $\alpha, \beta$ are smoothing parameters
#
# ## Is Holt’s method suitable for electricity data?
#
# It can capture a trend, but **cannot model seasonality**. For electricity data, it will still miss the daily/weekly cycles.

# %%
fcst_holt = StatsForecast(
    models=[AutoETS(season_length=48, model="AAN", alias="Holt", damped=False)],
    freq="30m",
)
holt_fit = fcst_holt.fit(df=data)
holt_forecast = fcst_holt.cross_validation(
    df=data.select([id_, time_, target_col.forward_fill()]),
    h=48,
    step_size=1,
    n_windows=1,
    fitted=True,
).drop("cutoff")
plot_series(data, holt_forecast, max_insample_length=200)

# %% [markdown]
# ## Interpretation
#
# - Holt’s method will forecast a straight line (with trend), but **no repeating cycles**.
# - However, the forecast for electricity load is still a straight (but sloped) line because the model only captures the overall direction (up or down) in the data, not the repeating daily or weekly cycles. Since electricity consumption is highly seasonal, the model’s forecasts do not reflect the actual ups and downs—just a smooth extension of the last estimated level and trend.
# - For electricity, this is still not enough, but it’s a step up from SES.

# %%
model_dict = holt_fit.fitted_[0, 0].model_
states = model_dict["states"]
residuals = model_dict["residuals"]

plot_ets_components(
    time=data.get_column(time_),
    observed=data.get_column(target_),
    level=states[:, 0],
    slope=states[:, 1],
    season=None,
    resid=residuals,
)

# %%
print_ets_fitted_summary(holt_fit, model_alias="Holt", model_idx=0)

# %% [markdown]
# ### Explanation of Fitted Parameters
#
# - **alpha ($\alpha$): 0.6635**
#     The smoothing parameter for the **level**. Higher values mean the model gives more weight to recent observations when updating the level.
#
# - **beta ($\beta$): 0.0001**
#     The smoothing parameter for the **trend**. A very small value means the trend is updated very slowly, so the estimated trend changes little over time.
#
# - **gamma ($\gamma$): nan**
#     The smoothing parameter for **seasonality**. Here it is `nan` because this model does **not** include a seasonal component.
#
# - **phi ($\phi$): nan**
#     The **damping parameter** for the trend. Here it is `nan` because the model does **not** use a damped trend.
#
# - **initial level: 0.3434**
#     The starting value for the level component at the beginning of the series.
#
# - **initial trend: -0.0001**
#     The starting value for the trend component at the beginning of the series.
#
# **Summary:**
# These parameters control how the model updates its estimates of the level and trend at each time step. Since $\gamma$ and $\phi$ are `nan`, there is no seasonal component and no damping in this model. The initial values set the starting point for the model's recursive calculations.

# %% [markdown]
# # Part 3: Holt-Winters Additive Seasonality (ETS(A,A,A))
#
# ## Overview
#
# **Holt-Winters Additive (HWA)** is one of the most powerful and widely-used exponential smoothing models. It is suitable for data with:
# - **Trend** (persistent directional change)
# - **Additive seasonality** (seasonal effects that are roughly constant in magnitude)
#
# **Additive seasonality** means the seasonal effect is added to the trend, and the size of seasonal swings doesn't depend on the overall level. For example, electricity might peak by 0.5 kW above the trend every morning, and this 0.5 kW swing remains roughly the same whether the baseline is 1 kW or 3 kW.
#
# The model maintains **three components**: level, trend, and seasonal.
#
# ## State-Space Formulation
#
# The **measurement equation**:
#
# $$y_t = \ell_{t-1} + b_{t-1} + s_{t-m} + \varepsilon_t$$
#
# The **state equations** (three of them):
#
# $$\ell_t = \alpha (y_t - s_{t-m}) + (1-\alpha)(\ell_{t-1} + b_{t-1})$$
#
# $$b_t = \beta (\ell_t - \ell_{t-1}) + (1-\beta) b_{t-1}$$
#
# $$s_t = \gamma (y_t - \ell_{t-1} - b_{t-1}) + (1-\gamma) s_{t-m}$$
#
# The **forecast equation**:
#
# $$\hat{y}_{t+h|t} = \ell_t + h \cdot b_t + s_{t+h-m^*}$$
#
# where $h^* = ((h-1) \mod m) + 1$ ensures we cycle through seasonal indices.
#
# **Key Parameters:**
#
# - $\ell_t$: Level at time $t$
# - $b_t$: Trend at time $t$
# - $s_t$: Seasonal component at time $t$ (deviation from trend)
# - $m$: Season length (e.g., $m=48$ for daily, $m=336$ for weekly)
# - $\alpha, \beta, \gamma$: Smoothing parameters
#
# ## Detailed Mechanics
#
# ### Deseasonalization: The Level Update
#
# The crucial insight in HWA is that we **remove the seasonal component** before updating the level:
#
# $$\ell_t = \alpha (y_t - s_{t-m}) + (1-\alpha)(\ell_{t-1} + b_{t-1})$$
#
# Breaking this down:
#
# 1. **$(y_t - s_{t-m})$**: Subtract last year's (or season's) seasonal component from the current observation
#    - This gives us the "deseasonalized" observation—an estimate of what the level is now
# 2. **Blend with the expected level**: $(\ell_{t-1} + b_{t-1})$ is where we expected the level to be (last level + trend)
# 3. **Weight the blend**: $\alpha$ controls how much we trust the deseasonalized observation vs. our prediction
#
# **Why deseasonalize?** If we didn't remove the seasonal component, the level would bounce up and down with the seasonal pattern, rather than tracking the true underlying level.
#
# ### Trend Update
#
# The trend update is identical to Holt's method:
#
# $$b_t = \beta (\ell_t - \ell_{t-1}) + (1-\beta) b_{t-1}$$
#
# This captures how much the level actually changed (after removing seasonality), weighted against inertia from the previous trend.
#
# ### Seasonal Update
#
# The seasonal component is updated as:
#
# $$s_t = \gamma (y_t - \ell_{t-1} - b_{t-1}) + (1-\gamma) s_{t-m}$$
#
# Breaking this down:
#
# 1. **$(y_t - \ell_{t-1} - b_{t-1})$**: The residual after removing level and trend effects
#    - This is the "seasonal deviation" for this period
# 2. **Blend with past seasonal value**: Combine with the seasonal value from $m$ periods ago
# 3. **Weight the blend**: $\gamma$ controls how much the seasonal pattern adapts
#
# **Intuition:** If a particular hour of the day usually has a 0.3 kW deviation (additive), and today at that hour we see a 0.35 kW deviation, the seasonal estimate updates toward 0.35. But it keeps memory of the 0.3 value because $\gamma$ is typically small (e.g., 0.1).
#
# ### Seasonality Recycling in Forecasts
#
# The forecast uses **cyclic seasonal components**:
#
# $$\hat{y}_{t+h|t} = \ell_t + h \cdot b_t + s_{t+h-m^*}$$
#
# where we cycle back through the seasonal indices. For electricity with $m=48$:
#
# - $h=1$: Use $s_{t+1-48}$ (seasonal component from 48 periods ago / "same time tomorrow")
# - $h=2$: Use $s_{t+2-48}$ (same time tomorrow, but one period later)
# - $h=49$: Use $s_{t+49-48} = s_{t+1}$ (cycle back to first seasonal index)
#
# This ensures the forecast continues the seasonal pattern indefinitely, which is appropriate for periodic phenomena like electricity demand.
#
# ## Prediction Intervals
#
# For additive HWA, the prediction interval for h-step ahead forecast is:
#
# $$\hat{y}_{t+h|t} \pm z_{\alpha/2} \hat{\sigma} \sqrt{1 + \frac{h}{m} - \frac{1}{m}}$$
#
# where $\hat{\sigma}$ is the estimated one-step forecast error standard deviation. The interval grows with $h$, reflecting increased uncertainty further in the future.
#
# ## When to Use Additive vs Multiplicative Seasonality
#
# **Choose Additive (AAA) when:**
# - Seasonal swings are roughly the same magnitude regardless of the level
# - Example: A household peaks about 0.5 kW above baseline whether the baseline is 1 kW or 3 kW
# - More common for: Individual households, where peak loads are physically limited
#
# **Choose Multiplicative (AAM) when:**
# - Seasonal swings grow/shrink with the level
# - Example: When baseline demand is 2 kW, peak is 2.4 kW (20% swing); when baseline is 4 kW, peak is 4.8 kW (still 20%)
# - More common for: Aggregated loads, percentage-based variations
#
# ## Parameter Estimation and Ranges
#
# Parameters are estimated by maximum likelihood:
#
# $$\text{SSE}(\alpha, \beta, \gamma) = \sum_{t=1}^n (y_t - \ell_{t-1} - b_{t-1} - s_{t-m})^2$$
#
# This requires **three-dimensional optimization**. Typical ranges:
#
# | Parameter | Typical Range | Interpretation |
# |-----------|--------------|-----------------|
# | $\alpha$  | [0.1, 0.9]   | Level adaptation speed |
# | $\beta$   | [0.01, 0.3]  | Trend adaptation speed (usually small) |
# | $\gamma$  | [0.01, 0.3]  | Seasonal adaptation speed (usually small) |
#
# ## Suitability for Electricity Data
#
# Holt-Winters Additive is **generally suitable** for electricity consumption data because:
#
# 1. ✅ **Captures seasonality:** Can model daily (48 periods) and weekly (336 periods) patterns
# 2. ✅ **Captures trends:** Can handle gradual changes in demand levels
# 3. ✅ **Interpretable components:** You can see level, trend, and seasonal effects separately
# 4. ✅ **Computationally efficient:** Runs quickly even for millions of series
#
# **Limitations for electricity:**
#
# 1. ❌ **Single seasonality only:** Real electricity data has **multiple seasonalities** (daily, weekly, and possibly annual)
#    - HWA with $m=48$ captures the daily pattern but smooths over the weekly variation
#    - HWA with $m=336$ captures the weekly pattern but misses the daily peaks
#    - You can't set $m$ to capture both simultaneously
#
# 2. ❌ **Residual structure remains:** Even with HWA, residuals show autocorrelation at non-primary seasonal lags
#    - Example: If you use daily seasonality, the residuals still have autocorrelation at the weekly lag
#    - This indicates unmodeled structure remains
#
# 3. ❌ **No handling of calendar effects:** HWA doesn't naturally handle special days (holidays, events)
#
# ## Example: Electricity at Household vs Aggregated Level
#
# **For a single household:**
# - Additive HWA works well because seasonal swings are relatively stable
# - Trend is often minimal (demand is fairly stable across seasons)
# - Daily seasonality ($m=48$) is the most important frequency
#
# **For aggregated data (many households or a whole building):**
# - Multiplicative seasonality might be better (larger loads have larger swings)
# - Multiple seasonal patterns become more important
# - Trend may be more pronounced (long-term growth in demand)
#
# ---
#
# **Summary:** Holt-Winters Additive is the workhorse model for electricity forecasting, capturing both trend and seasonal patterns with interpretable components. However, its single-seasonality limitation means it cannot fully model the multi-frequency nature of real electricity data. For state-of-the-art results, methods like TBATS, Prophet, or MSTL are needed.

# %%
fcst_hw = StatsForecast(
    models=[
        AutoETS(season_length=48 * 7, model="AAA", alias="AdditiveHW", damped=False)
    ],
    freq="30m",
)
hw_fit = fcst_hw.fit(df=data)
hw_forecast = fcst_hw.cross_validation(
    df=data.select([id_, time_, target_col.forward_fill()]),
    h=48,
    step_size=1,
    n_windows=1,
    fitted=True,
).drop("cutoff")
plot_series(data, hw_forecast, max_insample_length=200)

# %% [markdown]
# ## Interpretation
#
# - This model will capture both the overall trend and the repeating daily/weekly cycles.
# - For most electricity data, this is a **strong baseline**.

# %%
model_dict = hw_fit.fitted_[0, 0].model_
states = model_dict["states"]
residuals = model_dict["residuals"]

plot_ets_components(
    time=data.get_column(time_),
    observed=data.get_column(target_),
    level=states[:, 0],
    slope=states[:, 1],
    season=states[:, 2],
    resid=residuals,
)

# %%
print_ets_fitted_summary(hw_fit, model_alias="Damped Holt", model_idx=0)

# %% [markdown]
# ### Multiplicative Holt-Winters
# (ETS(A,A,M) or ETS(M,A,M)) is a version of the Holt-Winters method where the seasonal component is multiplied rather than added. This means the size of the seasonal effect changes proportionally with the level of the series: when the overall demand is higher, the seasonal swings are larger; when demand is lower, the swings are smaller. The equations for the multiplicative model are:
#
# - **Level:** $\ell_t = \alpha \frac{y_t}{s_{t-m}} + (1-\alpha)(\ell_{t-1} + b_{t-1})$
# - **Trend:** $b_t = \beta (\ell_t - \ell_{t-1}) + (1-\beta) b_{t-1}$
# - **Seasonality:** $s_t = \gamma \frac{y_t}{\ell_{t-1} + b_{t-1}} + (1-\gamma) s_{t-m}$
# - **Forecast:** $\hat{y}_{t+h} = (\ell_t + h b_t) s_{t-m+h^*}$
#
# **When is multiplicative HW appropriate?**
# - Use multiplicative seasonality when the amplitude of the seasonal pattern increases as the level of the series increases (i.e., the seasonal effect is not constant but grows/shrinks with demand).
# - For electricity load, multiplicative HW is often appropriate for **aggregated data** (e.g., city or region), where higher demand periods (like winter) have larger daily swings.
# - For **individual households** (like this dataset), the seasonal effect is often more stable (additive), since the maximum possible load is limited and the pattern doesn't scale up and down as much.
# - If you plot the data and see that the difference between daily peaks and troughs gets bigger when the overall level is higher, multiplicative HW may be a better fit. If the seasonal swings are roughly the same size regardless of the level, additive HW is preferred.
#
# **Summary:**
# - Multiplicative HW is best when seasonal variation grows with the level.
# - For this household electricity data, additive HW is usually more suitable, but you can try both and compare the fit.

# %% [markdown]
# # Part 4: Holt-Winters Multiplicative Seasonality (ETS(A,A,M))
#
# ## Overview
#
# **Holt-Winters Multiplicative (HWM)** is a variant of Holt-Winters where the seasonal component is **multiplied** by the level rather than added. This model is suitable when:
# - **Trend and seasonality** are both present
# - **Seasonal swings scale with the level** (higher demand → larger swings, lower demand → smaller swings)
#
# For example, if morning electricity demand is typically 1.2 times the baseline, this 20% premium applies whether the baseline is 1 kW or 5 kW.
#
# ## Additive vs Multiplicative: When to Choose?
#
# ### Decision Rule
#
# **Use Additive (AAA) when:**
# - Seasonal effect is **constant in magnitude**
# - Example: Morning peak is +0.3 kW regardless of baseline level
# - Plot characteristic: Seasonal swings appear as roughly equal-sized bumps regardless of vertical position
#
# **Use Multiplicative (AAM) when:**
# - Seasonal effect is **proportional to the level**
# - Example: Morning peak is 1.3× the trend (30% above baseline)
# - Plot characteristic: Seasonal swings get bigger when the overall level is higher
#
# ### Visual Examples
#
# **Additive Pattern:**
# ```
# Level 1 kW: |  peak: 1.3 |  valley: 0.7  | gap = 0.6
# Level 3 kW: |  peak: 3.3 |  valley: 2.7  | gap = 0.6  (same gap)
# ```
#
# **Multiplicative Pattern:**
# ```
# Level 1 kW: |  peak: 1.3  |  valley: 0.7  | ratio = 1.3/0.7 ≈ 1.86
# Level 3 kW: |  peak: 3.9  |  valley: 2.1  | ratio = 3.9/2.1 ≈ 1.86  (same ratio)
# ```
#
# ## State-Space Formulation
#
# The **measurement equation**:
#
# $$y_t = (\ell_{t-1} + b_{t-1}) s_{t-m} + \varepsilon_t$$
#
# The **state equations**:
#
# $$\ell_t = \alpha \frac{y_t}{s_{t-m}} + (1-\alpha)(\ell_{t-1} + b_{t-1})$$
#
# $$b_t = \beta (\ell_t - \ell_{t-1}) + (1-\beta) b_{t-1}$$
#
# $$s_t = \gamma \frac{y_t}{\ell_{t-1} + b_{t-1}} + (1-\gamma) s_{t-m}$$
#
# The **forecast equation**:
#
# $$\hat{y}_{t+h|t} = (\ell_t + h \cdot b_t) \cdot s_{t+h-m^*}$$
#
# ## Detailed Mechanics
#
# ### Seasonal Indices as Multipliers
#
# In the multiplicative model, seasonal components $s_t$ are **multipliers**, not additions:
#
# - $s_t = 1.0$ means no seasonal effect (neutral)
# - $s_t = 1.3$ means 30% above trend
# - $s_t = 0.7$ means 30% below trend
# - $s_t = 1.2$ means 20% above trend
#
# This is fundamentally different from additive, where $s_t$ represents an absolute deviation.
#
# ### Deseasonalization via Division
#
# To extract the level from an observation that has seasonal multiplier effects:
#
# $$\ell_t = \alpha \frac{y_t}{s_{t-m}} + (1-\alpha)(\ell_{t-1} + b_{t-1})$$
#
# We **divide** rather than subtract:
#
# 1. **$\frac{y_t}{s_{t-m}}$**: Divide the observation by last season's seasonal index
#    - This removes the multiplicative seasonal effect
#    - Gives us the deseasonalized value (level + trend)
# 2. **Blend with expected level**: Combine with $\ell_{t-1} + b_{t-1}$
# 3. **Weight the blend**: Parameter $\alpha$ controls the blend
#
# ### Trend Update
#
# Unchanged from additive:
#
# $$b_t = \beta (\ell_t - \ell_{t-1}) + (1-\beta) b_{t-1}$$
#
# ### Seasonal Index Update
#
# Similarly, seasonal components are updated via division:
#
# $$s_t = \gamma \frac{y_t}{\ell_{t-1} + b_{t-1}} + (1-\gamma) s_{t-m}$$
#
# Breaking this down:
#
# 1. **$\frac{y_t}{\ell_{t-1} + b_{t-1}}$**: Divide the observation by the expected level (previous level + trend)
#    - This extracts the "seasonal multiplier" for this period
# 2. **Blend with past seasonal index**: Combine with the seasonal index from $m$ periods ago
# 3. **Weight the blend**: Parameter $\gamma$ controls adaptation
#
# **Intuition:** If the seasonal index for "morning peak" is usually 1.2, and this morning we observe 1.25× the expected trend, the seasonal estimate updates toward 1.25.
#
# ### Forecast Profile
#
# The forecast applies the seasonal multiplier to the trend forecast:
#
# $$\hat{y}_{t+h|t} = (\ell_t + h \cdot b_t) \cdot s_{t+h-m^*}$$
#
# This means:
# - The trend component grows linearly with horizon: $\ell_t, \ell_t + b_t, \ell_t + 2b_t, \ldots$
# - The seasonal component cycles: $s_{t+1-m^*}, s_{t+2-m^*}, \ldots$
# - The forecast is their **product**, so when trend is high and seasonal index is high, forecasts spike
#
# ## Example: Electricity Forecast with Multiplicative HW
#
# Suppose at time $t$:
# - Level: $\ell_t = 2.0$ kW
# - Trend: $b_t = 0.01$ kW/period (very small upward trend)
# - Seasonal indices for next 4 periods: $s = [0.9, 0.8, 1.3, 1.2]$ (repeating daily pattern)
#
# One-period ahead forecasts:
# - $\hat{y}_{t+1|t} = (2.0 + 0.01) \times 0.9 = 1.809$ kW
# - $\hat{y}_{t+2|t} = (2.0 + 0.02) \times 0.8 = 1.616$ kW
# - $\hat{y}_{t+3|t} = (2.0 + 0.03) \times 1.3 = 2.639$ kW
# - $\hat{y}_{t+4|t} = (2.0 + 0.04) \times 1.2 = 2.448$ kW
#
# Notice how the seasonal pattern [0.9, 0.8, 1.3, 1.2] is preserved, but the magnitude grows slightly due to the trend (0.01 per period).
#
# ## Comparison: Additive vs Multiplicative
#
# | Property | Additive (AAA) | Multiplicative (AAM) |
# |----------|----------------|----------------------|
# | Forecast | $\ell_t + hb_t + s_{t+h-m}$ | $(\ell_t + hb_t) \cdot s_{t+h-m}$ |
# | Seasonal component | Absolute deviation | Multiplier (ratio) |
# | Seasonal range | Can be any real number | Typically [0.5, 2.0] for realistic data |
# | Best for | Constant-sized seasonal effects | Seasonal effects that scale with level |
# | Example: low demand | 1 kW ± 0.3 kW = [0.7, 1.3] kW | 1 kW × [0.8, 1.2] = [0.8, 1.2] kW |
# | Example: high demand | 5 kW ± 0.3 kW = [4.7, 5.3] kW | 5 kW × [0.8, 1.2] = [4.0, 6.0] kW |
#
# **The key difference:** With additive, the swing from low to high demand is constant. With multiplicative, the swing is **proportional** to the demand level.
#
# ## Mathematical Constraints
#
# For multiplicative HW to be valid, we need:
#
# 1. **No zero or negative observations:** Since we divide by $y_t$ and $\ell_{t-1} + b_{t-1}$, these must be positive
#    - For electricity, this is usually satisfied
#    - But watch out for missing data coded as 0
#
# 2. **Seasonal indices should remain positive:** $s_t > 0$ always
#    - The update rule preserves this (weighted average of two positive numbers)
#
# 3. **Initial level should be positive:** $\ell_0 > 0$ to start the recursion
#
# ## Suitability for Electricity Data
#
# **For Individual Households (AAA usually better):**
# - Seasonal effects tend to be additive
# - Peak demand is often physically limited (can't exceed circuit capacity)
# - Additive captures the pattern well
#
# **For Aggregated Data (AAM often better):**
# - As you aggregate multiple households/buildings, multiplicative seasonality emerges
# - When demand triples, morning peaks also roughly triple
# - Multiplicative seasonality becomes more appropriate
#
# **For your specific data (MAC000193 household):**
# - Likely **additive is better** because it's a single household
# - But **try both** and compare using information criteria (AIC/BIC) or cross-validation
#
# ---
#
# **Summary:** Multiplicative seasonality is appropriate when seasonal effects scale with the level. The model uses division instead of subtraction for deseasonalization, and seasonal components are multipliers rather than additions. For aggregated electricity data, multiplicative HW often performs better than additive, though individual households typically show additive patterns.

# %%
fcst_hw_damped = StatsForecast(
    models=[
        AutoETS(
            season_length=48 * 7, model="AAA", damped=True, alias="DampedAdditiveHW"
        )
    ],
    freq="30m",
)
hw_damped_fit = fcst_hw_damped.fit(df=data)
hw_damped_forecast = fcst_hw_damped.cross_validation(
    df=data.select([id_, time_, target_col.forward_fill()]),
    h=48,
    step_size=1,
    n_windows=1,
    fitted=True,
).drop("cutoff")
plot_series(data, hw_damped_forecast, max_insample_length=200)

# %% [markdown]
# ## Interpretation
#
# - This model captures trend, seasonality, and damps the trend for long-term forecasts.
# - For electricity data, this is often the **most robust exponential smoothing model**.

# %%
model_dict = hw_damped_fit.fitted_[0, 0].model_
states = model_dict["states"]
residuals = model_dict["residuals"]

plot_ets_components(
    time=data.get_column(time_),
    observed=data.get_column(target_),
    level=states[:, 0],
    slope=states[:, 1],
    season=states[:, 2],
    resid=residuals,
)

# %%
print_ets_fitted_summary(hw_damped_fit, model_alias="Damped Holt", model_idx=0)

# %% [markdown]
# # Part 5: Damped Trend Models (ETS(A,Ad,A) and ETS(A,Ad,M))
#
# ## Overview
#
# **Damped trend** models modify Holt's method by adding a damping parameter $\phi \in (0, 1)$ that gradually reduces the trend's influence on forecasts. Instead of extrapolating the trend indefinitely, damped models make the trend **decay over time**, eventually flattening out.
#
# This is appropriate for electricity because:
# - Actual trends rarely continue at constant rates forever
# - Using damped trends produces more realistic long-term forecasts
# - Prevents the model from predicting unrealistic consumption levels 50 steps ahead
#
# ## The Problem with Linear Trends
#
# With Holt's method, the forecast is:
#
# $$\hat{y}_{t+h|t} = \ell_t + h \cdot b_t$$
#
# If $b_t = 0.02$ kW per half-hour (positive trend), forecasts grow indefinitely:
# - 1 step ahead: $\ell_t + 0.02$
# - 10 steps ahead: $\ell_t + 0.20$
# - 100 steps ahead: $\ell_t + 2.00$
#
# For electricity, a 0.02 kW trend per 30 minutes is 0.04 kW per hour, or ~1 kW per day. Over 100 days, this predicts consumption grows by 100 kW—unrealistic for a household with typical demand under 10 kW!
#
# ## State-Space Formulation
#
# The **measurement equation** (for additive damped):
#
# $$y_t = \ell_{t-1} + \phi b_{t-1} + s_{t-m} + \varepsilon_t$$
#
# Notice: We use $\phi b_{t-1}$ instead of just $b_{t-1}$. The damping parameter **reduces** the trend contribution at each step.
#
# The **state equations**:
#
# $$\ell_t = \alpha (y_t - s_{t-m}) + (1-\alpha)(\ell_{t-1} + \phi b_{t-1})$$
#
# $$b_t = \beta (\ell_t - \ell_{t-1}) + (1-\beta) \phi b_{t-1}$$
#
# $$s_t = \gamma (y_t - \ell_{t-1} - \phi b_{t-1}) + (1-\gamma) s_{t-m}$$
#
# The **forecast equation**:
#
# $$\hat{y}_{t+h|t} = \ell_t + \left(\sum_{j=1}^h \phi^j\right) b_t + s_{t+h-m^*}$$
#
# The sum simplifies to:
#
# $$\sum_{j=1}^h \phi^j = \frac{\phi(1 - \phi^h)}{1 - \phi}$$
#
# So:
#
# $$\hat{y}_{t+h|t} = \ell_t + b_t \frac{\phi(1 - \phi^h)}{1 - \phi} + s_{t+h-m^*}$$
#
# ## Understanding the Damping Parameter
#
# ### The Geometric Series
#
# The forecast trend component uses a geometric series:
#
# $$\phi^1 + \phi^2 + \phi^3 + \cdots + \phi^h$$
#
# With $\phi \in (0, 1)$, each term is smaller than the previous:
# - $\phi = 0.99$: Series converges slowly (trend persists longer)
# - $\phi = 0.90$: Series converges moderately
# - $\phi = 0.80$: Series converges quickly (trend fades fast)
#
# ### Asymptotic Behavior
#
# As $h \to \infty$:
#
# $$\lim_{h \to \infty} \sum_{j=1}^h \phi^j = \frac{\phi}{1 - \phi}$$
#
# This means the forecast **asymptotically approaches**:
#
# $$\hat{y}_{\infty} = \ell_t + b_t \frac{\phi}{1 - \phi} + \text{seasonal component}$$
#
# The trend contribution doesn't grow indefinitely; it levels off at a fixed value $b_t \frac{\phi}{1 - \phi}$.
#
# ### Examples with Specific Values
#
# For $b_t = 0.02$ kW/period:
#
# **$\phi = 0.99$ (weak damping):**
# - $\sum_{j=1}^{\infty} \phi^j = 99$
# - Asymptotic trend component: $0.02 \times 99 = 1.98$ kW
# - Forecasts 100 steps ahead still mostly follow the trend
#
# **$\phi = 0.95$ (moderate damping):**
# - $\sum_{j=1}^{\infty} \phi^j = 19$
# - Asymptotic trend component: $0.02 \times 19 = 0.38$ kW
# - Trend effect is much smaller long-term
#
# **$\phi = 0.90$ (stronger damping):**
# - $\sum_{j=1}^{\infty} \phi^j = 9$
# - Asymptotic trend component: $0.02 \times 9 = 0.18$ kW
# - Trend effect decays quickly
#
# ## Half-Life Calculation
#
# A useful measure is the **half-life** $h^*$: how many steps until the trend contribution drops to half its current value?
#
# $$\phi^{h^*} = 0.5$$
#
# Solving:
#
# $$h^* = \frac{\ln(0.5)}{\ln(\phi)} = \frac{-0.693}{\ln(\phi)}$$
#
# **Examples:**
# - $\phi = 0.99$: $h^* = \frac{-0.693}{-0.00436} \approx 159$ periods
# - $\phi = 0.95$: $h^* = \frac{-0.693}{-0.0513} \approx 13.5$ periods
# - $\phi = 0.90$: $h^* = \frac{-0.693}{-0.105} \approx 6.6$ periods
# - $\phi = 0.80$: $h^* = \frac{-0.693}{-0.223} \approx 3.1$ periods
#
# **For electricity at 30-minute resolution:**
# - $\phi = 0.98$: Trend persists ~110 periods (55 hours)
# - $\phi = 0.95$: Trend persists ~13.5 periods (6.75 hours)
# - $\phi = 0.90$: Trend persists ~6.6 periods (3.3 hours)
#
# ## Forecast Profile Comparison
#
# **Without damping (Holt, $\phi$ implicit = 1.0):**
#
# At $t=0$: $\ell_0 = 2.0$, $b_0 = 0.05$
#
# | Horizon | Forecast |
# |---------|----------|
# | $h=1$   | $2.0 + 0.05 = 2.05$   |
# | $h=10$  | $2.0 + 0.50 = 2.50$   |
# | $h=50$  | $2.0 + 2.50 = 4.50$   |
# | $h=100$ | $2.0 + 5.00 = 7.00$   |
#
# **With damping ($\phi = 0.95$):**
#
# | Horizon | Forecast |
# |---------|----------|
# | $h=1$   | $2.0 + 0.05 \times 0.95 = 2.0475$   |
# | $h=10$  | $2.0 + 0.05 \times \frac{0.95(1-0.95^{10})}{1-0.95} = 2.0 + 0.0571 \approx 2.057$   |
# | $h=50$  | $2.0 + 0.05 \times \frac{0.95(1-0.95^{50})}{1-0.95} \approx 2.0 + 0.247 = 2.247$   |
# | $h=100$ | $2.0 + 0.05 \times \frac{0.95}{1-0.95} = 2.0 + 0.95 = 2.95$ (asymptotic) |
#
# **Notice:** With damping, the forecast levels off around 2.95 instead of growing to 7.00.
#
# ## Parameter Estimation
#
# The damping parameter $\phi$ can be:
#
# 1. **Estimated via likelihood:** Included in the optimization alongside $\alpha, \beta, \gamma$
#    - Requires 4-dimensional optimization (more complex)
#    - Provides flexibility but can be unstable if data lacks clear trend
#
# 2. **Fixed a priori:** Set $\phi = 0.98$ or similar based on domain knowledge
#    - Simpler optimization (3-dimensional)
#    - More stable for short series
#
# 3. **From literature:** Common values are $\phi \in [0.95, 0.99]$
#    - $\phi = 0.98$: Default in many software packages
#    - $\phi = 0.95$: Stronger damping, more conservative long-term forecasts
#
# ## Suitability for Electricity Data
#
# **Advantages:**
# - ✅ **Realistic long-term forecasts:** Prevents unrealistic extrapolation
# - ✅ **Captures short-term trend:** Still responds to recent patterns
# - ✅ **Works for stationary data:** Even if there's no real trend, damping does no harm
# - ✅ **Seasonality + damped trend:** Perfect for electricity that lacks long-term trend but needs seasonal capture
#
# **For your household data:**
# - Electricity consumption is largely **stationary** (no significant upward/downward trend)
# - A damped trend model works well because:
#   - If trend is zero, damping has minimal effect
#   - If there's a temporary anomaly, damping prevents over-extrapolation
#   - Protects long-horizon forecasts
#
# **Trade-offs:**
# - Requires estimating one additional parameter ($\phi$)
# - More complex than non-damped models
# - For very short forecasting horizons ($h < 10$), the difference is minimal
#
# ## ETS Notation for Damped Models
#
# - **ETS(A, Ad, A):** Additive error, additive damped trend, additive seasonality
# - **ETS(A, Ad, M):** Additive error, additive damped trend, multiplicative seasonality
# - **ETS(M, Ad, M):** Multiplicative error, additive damped trend, multiplicative seasonality
#
# The "Ad" in the trend position indicates damped additive trend. Similarly, "Md" would indicate damped multiplicative trend.
#
# ---
#
# **Summary:** Damped trends prevent unrealistic infinite extrapolation by having the trend decay asymptotically. The damping parameter $\phi$ controls the rate of decay. Damped models are essential for realistic long-term electricity forecasts, especially for stationary household data where trend should not persist forever.

# %%
fcst_damped = StatsForecast(
    models=[
        AutoETS(
            season_length=48 * 7, model="AAN", damped=True, phi=0.9, alias="Damped Holt"
        )
    ],
    freq="30m",
)
damped_fit = fcst_damped.fit(df=data)
damped_forecast = fcst_damped.cross_validation(
    df=data.select([id_, time_, target_col.forward_fill()]),
    h=48,
    step_size=1,
    n_windows=1,
    fitted=True,
).drop("cutoff")
plot_series(data, damped_forecast, max_insample_length=200)

# %% [markdown]
# ## Interpretation
#
# - Similar to what we saw above with Holt's method, doesn't work so well since there is no trend in electricity load
# - Still, **no seasonality** is captured, so daily/weekly cycles are missed.

# %%
print_ets_fitted_summary(damped_fit, model_alias="Damped Holt", model_idx=0)

# %% [markdown]
# # Summary Table: Model Suitability for Electricity Forecasting
#
# | Model                        | Trend | Seasonality | Damped | Suitable for Electricity? |
# |------------------------------|-------|-------------|--------|--------------------------|
# | Simple Exponential Smoothing |   ✗   |      ✗      |   ✗    |            ✗             |
# | Holt’s Linear Trend          |   ✓   |      ✗      |   ✗    |            ✗             |
# | Damped Holt                  |   ✓   |      ✗      |   ✓    |            ✗             |
# | Holt-Winters Additive        |   ✓   |      ✓      |   ✗    |            ✓             |
# | Damped Holt-Winters Additive |   ✓   |      ✓      |   ✓    |            ✗             |
#
# For electricity consumption, always use a model with **seasonality** (and usually with a damped trend for long-term forecasts).

# %% [markdown]
# # Residual Analysis for Holt-Winters Additive Model
#
# Residual analysis helps us check whether the model has captured all the structure in the data. Ideally, the residuals (the differences between the observed values and the fitted values) should look like white noise: no pattern, no autocorrelation, and roughly constant variance.
#
# Let's analyze the residuals from the Holt-Winters Additive model.

# %%
# Plot residual diagnostics
plot_residuals_diagnostic(time=data.get_column(time_), residuals=residuals)

# %%
# Apply Ljung-Box test to residuals
resid_test = acorr_ljungbox(residuals)
resid_test

# %% [markdown]
# # Part 6: Complete ETS Framework and All 30 Models
#
# ## The Complete ETS Family
#
# We've explored individual exponential smoothing models throughout this notebook. In this section, we systematize them using the **ETS (Error-Trend-Seasonal)** framework, which provides a unified taxonomy of all possibilities.
#
# ## ETS Notation System
#
# Each ETS model is specified by a three-component code: **ETS(E, T, S)**
#
# ### Component 1: Error Type (E)
#
# - **A (Additive):** Error is added to the model
#   - Measurement: $y_t = \ell_{t-1} + b_{t-1} + s_{t-m} + \varepsilon_t$
#   - Error component has the same scale as the data
#   - Better when variability is stable
#
# - **M (Multiplicative):** Error is multiplied by the level
#   - Measurement: $y_t = (\ell_{t-1} + b_{t-1}) s_{t-m} (1 + \varepsilon_t)$
#   - Error component scales with the data magnitude
#   - Better when variability increases with level
#
# ### Component 2: Trend Type (T)
#
# - **N (None):** No trend component
#   - Model: $y_t = \ell_{t-1} + s_{t-m} + \varepsilon_t$
#   - Forecast: $\hat{y}_{t+h} = \ell_t + s_{t+h-m^*}$
#
# - **A (Additive):** Linear trend (constant slope)
#   - Model: $y_t = \ell_{t-1} + b_{t-1} + s_{t-m} + \varepsilon_t$
#   - Forecast: $\hat{y}_{t+h} = \ell_t + hb_t + s_{t+h-m^*}$
#   - Suitable when trend is relatively constant
#
# - **Ad (Additive Damped):** Linear trend that decays
#   - Model: $y_t = \ell_{t-1} + \phi b_{t-1} + s_{t-m} + \varepsilon_t$
#   - Forecast: $\hat{y}_{t+h} = \ell_t + b_t \frac{\phi(1-\phi^h)}{1-\phi} + s_{t+h-m^*}$
#   - Suitable for trend that shouldn't persist forever
#
# - **M (Multiplicative):** Trend that scales with level
#   - Model: $y_t = \ell_{t-1}(1 + b_{t-1}) + s_{t-m} + \varepsilon_t$
#   - Forecast: $\hat{y}_{t+h} = \ell_t (1 + b_t)^h + s_{t+h-m^*}$
#   - Suitable when trend is exponential (e.g., percentage growth)
#
# - **Md (Multiplicative Damped):** Exponential trend that decays
#
# ### Component 3: Seasonality Type (S)
#
# - **N (None):** No seasonal component
#   - Model: $y_t = \ell_{t-1} + b_{t-1} + \varepsilon_t$
#   - Data has no repeating pattern
#
# - **A (Additive):** Seasonal effect is added
#   - Seasonal component: $s_t = \gamma(y_t - \ell_{t-1} - b_{t-1}) + (1-\gamma)s_{t-m}$
#   - Seasonal swings are roughly constant in magnitude
#   - Example: +0.3 kW morning peak regardless of demand level
#
# - **M (Multiplicative):** Seasonal effect multiplies
#   - Seasonal component: $s_t = \gamma \frac{y_t}{\ell_{t-1} + b_{t-1}} + (1-\gamma)s_{t-m}$
#   - Seasonal swings scale with level
#   - Example: 1.2× morning peak regardless of demand level
#
# ## All 30 Possible ETS Models
#
# With 2 error types, 5 trend types, and 3 seasonality types, we have $2 \times 5 \times 3 = 30$ possible models.
#
# ### Common Models for Electricity
#
# | Model Code | Error | Trend | Season | Additive/Multiplicative Components | Use Case |
# |------------|-------|-------|--------|-----|-----------|
# | ETS(A,N,N) | A | None | None | All additive | Baseline, no pattern data |
# | ETS(A,A,N) | A | Linear | None | Level + trend, no seasonality | Trending data (unusual for electricity) |
# | ETS(A,Ad,N) | A | Damped | None | Damped trend, no seasonality | Short-term trend that fades |
# | ETS(A,N,A) | A | None | Additive | Level + seasonality, no trend | Seasonal, no trend (some buildings) |
# | ETS(A,A,A) | A | Linear | Additive | All additive | **Electricity workhorse** |
# | ETS(A,Ad,A) | A | Damped | Additive | Damped trend + additive season | Best for stationary household data |
# | ETS(M,N,M) | M | None | Multiplicative | Multiplicative components | Seasonal no trend (multiplicative) |
# | ETS(M,A,M) | M | Linear | Multiplicative | All multiplicative | Exponential growth + multiplicative season |
# | ETS(M,Ad,M) | M | Damped | Multiplicative | Damped exponential + multiplicative season | Aggregated data (many buildings) |
#
# ### Decision Tree for Model Selection
#
# ```
# Does data have TREND?
# ├─ NO ────────────────────────────────────┐
# │  Does data have SEASONALITY?             │
# │  ├─ NO: Use ETS(A,N,N) or ETS(M,N,N)    │
# │  └─ YES:                                │
# │     Additive or Multiplicative?         │
# │     ├─ Additive: Use ETS(A,N,A)         │
# │     └─ Multiplicative: Use ETS(M,N,M)  │
# │                                         │
# └─ YES ────────────────────────────────┐
#    Should trend damp? (usually YES!)     │
#    └─ NO:                               │
#       Does data have SEASONALITY?        │
#       ├─ NO: Use ETS(A,A,N)             │
#       └─ YES:                           │
#          Additive or Multiplicative?    │
#          ├─ Additive: Use ETS(A,A,A)   │
#          └─ Multiplicative: Use ETS(A,A,M)
#
#    └─ YES: (DAMPED)
#       Does data have SEASONALITY?
#       ├─ NO: Use ETS(A,Ad,N)
#       └─ YES:
#          Additive or Multiplicative?
#          ├─ Additive: Use ETS(A,Ad,A)    ← Best for electricity
#          └─ Multiplicative: Use ETS(A,Ad,M)
# ```
#
# ## Likelihood and Model Selection
#
# ### General State-Space Form
#
# All ETS models can be written as:
#
# $$y_t = h(\mathbf{x}_{t-1}) + \varepsilon_t$$
# $$\mathbf{x}_t = f(\mathbf{x}_{t-1}) + g(\mathbf{x}_{t-1})\varepsilon_t$$
#
# where:
# - $h(\cdot)$ is the measurement function
# - $f(\cdot)$ is the state evolution function
# - $g(\cdot)$ is the error distribution function
# - $\mathbf{x}_t$ is the state vector (level, trend, seasonal)
#
# ### Likelihood for Additive Error
#
# For additive error models with $\varepsilon_t \sim N(0, \sigma^2)$:
#
# $$L(\boldsymbol{\theta}, \sigma^2) = \prod_{t=1}^n \frac{1}{\sigma\sqrt{2\pi}} \exp\left(-\frac{[y_t - h(\mathbf{x}_{t-1})]^2}{2\sigma^2}\right)$$
#
# $$\log L = -\frac{n}{2}\log(2\pi\sigma^2) - \frac{1}{2\sigma^2}\sum_{t=1}^n[y_t - h(\mathbf{x}_{t-1})]^2$$
#
# Maximum likelihood parameter estimation is equivalent to minimizing:
#
# $$\text{SSE} = \sum_{t=1}^n [y_t - h(\mathbf{x}_{t-1})]^2$$
#
# ### Model Comparison: Information Criteria
#
# To choose between models, use **information criteria** that penalize complexity:
#
# **AIC (Akaike Information Criterion):**
# $$\text{AIC} = 2k + n \log(\text{SSE}/n)$$
#
# **BIC (Bayesian Information Criterion):**
# $$\text{BIC} = k \log(n) + n \log(\text{SSE}/n)$$
#
# where $k$ is the number of parameters and $n$ is sample size.
#
# **Smaller AIC/BIC → Better model** (balances fit and complexity)
#
# BIC penalizes complexity more heavily, favoring simpler models.
#
# ## AutoETS Algorithm
#
# Modern ETS implementations use **AutoETS**: an automatic algorithm that searches over possible models.
#
# **Steps:**
# 1. Specify a subset of models to consider (e.g., only consider A/M error, N/A/Ad for trend)
# 2. For each model: Estimate parameters via maximum likelihood
# 3. Calculate information criterion (AIC/BIC)
# 4. Select model with lowest criterion
# 5. Return fitted model
#
# **Advantages:**
# - ✅ No manual model selection needed
# - ✅ Often finds good-performing models
# - ✅ Avoids over-fitting via information criteria
# - ✅ Scales to many series
#
# **Limitations:**
# - ❌ Can't capture domain knowledge (you know the pattern)
# - ❌ Computationally expensive with many models
# - ❌ May struggle with unusual patterns
# - ❌ Restricted to pre-defined model set
#
# ## Fundamental Limitations of ETS for Electricity
#
# Even with all 30 models, ETS has inherent limitations:
#
# 1. **Single seasonality only:**
#    - Real electricity has daily AND weekly AND annual seasonalities
#    - ETS can only model one via the seasonal component $s_t$
#
# 2. **Linear/multiplicative trends only:**
#    - Can't model more complex trend patterns
#    - Damping eventually forces convergence (no flexibility for actual trend)
#
# 3. **No exogenous variables:**
#    - Temperature, day-of-week indicators, holidays not built-in
#    - Must handle separately or use external methods
#
# 4. **Assumes same pattern everywhere:**
#    - One seasonality pattern for all periods
#    - Can't have different seasonal patterns for weekdays vs weekends
#    - Can't have different demand for working hours vs night
#
# 5. **Limited adaptation:**
#    - Parameters fixed after estimation
#    - No online learning to handle regime changes
#    - New holiday patterns might not be learned quickly
#
# ## When to Move Beyond ETS
#
# **Consider TBATS if:**
# - You have multiple seasonalities (daily + weekly + annual)
# - You want a single, unified model for all frequencies
#
# **Consider Prophet if:**
# - You want to handle holidays and special events explicitly
# - You need interpretable trend changepoints
# - You want to incorporate external regressors
#
# **Consider MSTL if:**
# - You want modular decomposition with clean seasonal separation
# - You prefer non-parametric smoothing
# - You want to apply different methods to different components
#
# **Consider Deep Learning if:**
# - You have massive amounts of data
# - Patterns are complex and non-stationary
# - You can afford computational cost
# - You have access to external data (weather, etc.)

# %% [markdown]
# # Part 7: Residual Diagnostics and Model Validation
#
# ## Why Residuals Matter
#
# **Residuals** are the forecast errors: $e_t = y_t - \hat{y}_{t|t-1}$. They represent what the model **didn't explain**. If a model is adequate, residuals should look like **white noise**: no pattern, no correlation, just random variation.
#
# If residuals have structure (patterns, autocorrelation), it means:
# - The model missed something important in the data
# - There's information left on the table
# - Forecasts could potentially be improved
#
# ## Properties of Ideal Residuals
#
# **Ideal residuals should have:**
#
# 1. **Zero mean:** $E[e_t] = 0$ (no systematic bias)
# 2. **Constant variance:** $\text{Var}[e_t] = \sigma^2$ (consistent prediction error)
# 3. **No autocorrelation:** $\text{Cov}[e_t, e_{t+k}] = 0$ for $k \neq 0$ (independence)
# 4. **Normality:** $e_t \sim N(0, \sigma^2)$ (Gaussian distribution)
#
# If residuals satisfy these properties, the model has captured all exploitable structure. If not, they're telling us something.
#
# ## Autocorrelation Analysis
#
# ### ACF: Autocorrelation Function
#
# The autocorrelation at lag $k$ is:
#
# $$\rho_k = \frac{\sum_{t=k+1}^n (e_t - \bar{e})(e_{t-k} - \bar{e})}{\sum_{t=1}^n (e_t - \bar{e})^2}$$
#
# where $\bar{e}$ is the mean of residuals. This measures how correlated the residual at time $t$ is with the residual at time $t-k$.
#
# **Interpretation:**
# - $\rho_k \approx 0$: No correlation at lag $k$ (good)
# - $\rho_k \approx 0.5$: Moderate positive correlation (problem)
# - $\rho_k \approx -0.5$: Moderate negative correlation (oscillating pattern, problem)
#
# **For white noise:** $\rho_k \sim N(0, 1/n)$, so under the null hypothesis of white noise, about 95% of sample ACFs should fall within $\pm 1.96/\sqrt{n}$.
#
# ### PACF: Partial Autocorrelation Function
#
# The partial autocorrelation at lag $k$ is the correlation at lag $k$ **after removing the effect of intermediate lags**:
#
# $$\phi_{kk} = \frac{\rho_k - \sum_{j=1}^{k-1} \phi_{k-1,j} \rho_{k-j}}{1 - \sum_{j=1}^{k-1} \phi_{k-1,j} \rho_j}$$
#
# This helps identify the order of autoregressive patterns in the data.
#
# ### Ljung-Box Test
#
# The **Ljung-Box test** formally tests whether residuals are white noise. The test statistic is:
#
# $$Q = n(n+2) \sum_{k=1}^h \frac{\rho_k^2}{n-k}$$
#
# Under the null hypothesis that residuals are white noise:
#
# $$Q \sim \chi^2_h$$
#
# where $h$ is the number of lags being tested (e.g., $h=20$).
#
# **Decision:**
# - If $p$-value $> 0.05$: Fail to reject null (residuals appear white noise)
# - If $p$-value $< 0.05$: Reject null (residuals have autocorrelation—model is inadequate)
#
# ## Normality Tests
#
# ### Q-Q Plot
#
# A **Q-Q plot** compares sample quantiles to theoretical normal quantiles. If residuals are normal, the plot should show a straight diagonal line. Deviations suggest:
# - Heavy tails: Outliers more common than expected
# - Skewness: Asymmetric distribution
# - Different central behavior: Non-normal middle
#
# ### Shapiro-Wilk Test
#
# The **Shapiro-Wilk test** formally tests normality:
#
# $$W = \frac{\left(\sum_{i=1}^n a_i x_{(i)}\right)^2}{\sum_{i=1}^n (x_i - \bar{x})^2}$$
#
# where $x_{(i)}$ are order statistics and $a_i$ are constants.
#
# - If $p$-value $> 0.05$: Residuals appear normal
# - If $p$-value $< 0.05$: Residuals deviate from normality
#
# ## Application to Electricity Data: HW Model
#
# When we fit Holt-Winters Additive to electricity data with $m=336$ (weekly seasonality), we expect the residuals to show:
#
# **Actually Observed:**
# - Strong autocorrelation at lags **48** (daily period)
# - Strong autocorrelation at lags around **100, 150, 200** (harmonics of daily)
# - Ljung-Box test: $p < 0.05$ (rejects white noise)
#
# **Why?**
# - The model captures the **weekly** pattern ($m=336$)
# - But it misses the **daily** pattern (which is faster, $m=48$)
# - The residuals still oscillate on a daily basis
#
# **Numerical Example:**
# ```
# Autocorrelation at lag 48:  ρ₄₈ = 0.35 (large positive correlation)
# Ljung-Box test p-value:     p < 0.001 (highly significant)
# Interpretation:             Residuals have strong daily oscillation
# ```
#
# This tells us: **"Your model works for weekly patterns but misses daily patterns."**
#
# ## Solutions for Multiple Seasonalities
#
# When standard ETS cannot handle multiple seasonalities adequately:
#
# ### 1. TBATS (Trigonometric Seasonality, Box-Cox Transformation, ARMA Errors, Trend, Seasonal)
# - Captures multiple seasonalities simultaneously
# - Uses Fourier terms for seasonal components
# - More parameters, requires more data
#
# ### 2. Prophet (Facebook)
# - Designed for business time series with multiple seasonalities
# - Handles trend changes, holidays, special events
# - Flexible model, easier parameter tuning
#
# ### 3. MSTL (Multiple Seasonal Trend decomposition using Loess)
# - Decomposes into multiple seasonal components + trend + remainder
# - Non-parametric approach
# - Pairs well with any forecasting method
#
# ### 4. Neural Network / Deep Learning
# - Learns multiple seasonal patterns automatically
# - Requires more data and computational power
# - State-of-the-art for complex patterns
#
# ## Residual Diagnostic Checklist
#
# When analyzing residuals, check:
#
# - [ ] **Mean close to zero:** $\bar{e} \approx 0$ (no bias)
# - [ ] **Constant variance:** Plot looks like random scatter around zero
# - [ ] **ACF small:** Most bars within $\pm 1.96/\sqrt{n}$ boundaries
# - [ ] **PACF small:** No significant spikes
# - [ ] **Ljung-Box:** $p$-value $> 0.05$ (white noise)
# - [ ] **Q-Q plot:** Points roughly on diagonal
# - [ ] **Shapiro-Wilk:** $p$-value $> 0.05$ (normality)
# - [ ] **No outliers:** No extreme values that dominate
# - [ ] **No patterns over time:** Residual plot shows no trends or cycles
#
# If residuals fail multiple checks, the model is inadequate.
#
# ## Beyond Residual Analysis
#
# Even with poor residual diagnostics, consider:
#
# 1. **Is the model appropriate for the application?**
#    - Maybe trading off 10% more residual correlation for model simplicity/speed is worthwhile
#
# 2. **Is the forecast horizon relevant?**
#    - If you only forecast 48 steps ahead (2 days), missing the weekly seasonality might matter less
#
# 3. **Is the frequency of data compatible with your forecast goal?**
#    - 30-minute data is detailed; maybe you need higher-level aggregation
#
# 4. **Can you ensemble multiple models?**
#    - Combine HW (weekly pattern) + ARIMA (daily pattern) + other models
#    - Often beats any single model
#
# ---
#
# **Summary:** Residual diagnostics tell whether your model has captured the main structure in the data. For electricity with multiple seasonalities, standard ETS will show autocorrelated residuals at missed frequencies. This isn't a failure—it's useful feedback for model improvement. Use it to decide whether to upgrade to TBATS, Prophet, MSTL, or other methods.

# %% [markdown]
# # Part 8: Comprehensive Summary and Practical Implementation
#
# ## Practical Electricity Forecasting Strategy
#
# ### For Single Household (like MAC000193)
#
# 1. **Start with:** ETS(A,Ad,A) with $m=48$ (daily seasonality)
#    - Good baseline, interpretable, fast
#
# 2. **Check residuals:** Look for autocorrelation at lag 336 (weekly)
#    - If significant: Acknowledge weekly pattern is missed
#    - If residuals white: Model is adequate for your use case
#
# 3. **Consider:**
#    - Is weekly pattern important for your forecasting goal?
#    - Is 48-hour ahead sufficient, or do you need longer?
#    - How often do you need to update the model?
#
# 4. **If unsatisfied:**
#    - Try TBATS or Prophet for better multi-seasonal capture
#    - Or use ETS(A,Ad,A) as baseline, then correct with separate weekly model
#
# ### For Building/Aggregated Level
#
# 1. **Start with:** ETS(A,Ad,M) with $m=336$ (weekly)
#    - Multiplicative seasonality more appropriate for aggregates
#    - Captures most variation
#
# 2. **Or use directly:** TBATS or Prophet
#    - More natural for business-level data
#    - Multi-seasonal support
#    - Holiday handling
#
# 3. **Consider ensemble:**
#    - ETS(A,Ad,A) at daily frequency
#    - ETS(A,Ad,M) at weekly frequency
#    - Prophet for holidays/events
#    - Average or weight predictions
#
# ## Key Insights from This Notebook
#
# 1. **ETS is recursive optimization:** Models minimize one-step forecast error using recursive updates, automatically discovering exponential weighting
#
# 2. **Smoothing parameters control adaptation speed:** $\alpha$ controls level responsiveness; $\beta$ and $\gamma$ typically much smaller for trend and seasonality stability
#
# 3. **Decomposition reveals structure:** Seeing level, trend, and seasonal separately helps understand data and validate model appropriateness
#
# 4. **No model captures everything:** All models make trade-offs; none are universally best. Use diagnostics and domain knowledge to choose.
#
# 5. **Forecasting is not just fitting:** Even a perfect in-sample fit doesn't guarantee good forecasts. Validation on hold-out test sets is essential.
#
# ## Next Steps
#
# - Implement cross-validation for your data
# - Compare multiple models quantitatively (RMSE, MAE, etc.)
# - Build confidence intervals via bootstrap or parametric methods
# - Create automated retraining pipeline
# - Monitor forecast performance over time and adjust models
#
# ---
#
# **Final Thought:**
#
# Exponential smoothing represents over 70 years of forecasting practice distilled into elegant recursive formulas. While modern deep learning gets headlines, ETS models remain the backbone of industrial forecasting because they're interpretable, efficient, and reliable. Understanding ETS deeply gives you the foundation to build better forecasting systems, whether you stick with ETS or graduate to more advanced methods.
#
# **Happy forecasting!**
